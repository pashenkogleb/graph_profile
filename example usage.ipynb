# %% [markdown]
# # install

# %% [markdown]
# # graph profile with temporary file

# %%
import graph_profile

# %%
def f(x):
    return g(3,x)


def g(x,y):
    return x+y

# %%
# %%graph_profile
#     f(2)
# Out:
#
# *** Profile stats marshalled to file '/tmp/tmp07qriwut.profile'.

# %% [markdown]
# # save output to specific file

# %%
import pandas as pd

# %%
# %%graph_profile 123.jpg
# df = pd.DataFrame()
# Out:
#
# *** Profile stats marshalled to file '/tmp/tmpi3t_o_y8.profile'.
